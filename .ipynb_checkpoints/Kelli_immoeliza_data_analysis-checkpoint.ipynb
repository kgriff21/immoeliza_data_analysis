# %%
import pandas as pd
from IPython.display import display
# import matplotlib.pyplot as plt

# Load your CSV file
df = pd.read_csv('Data/Raw/property_information_Kelli.csv')
# Display the first few rows in more readable format
display(df.head(10))
df.shape
# Out:
#    Unnamed: 0  Property ID  Locality data   Price Property type  \
# 0           0     20245694           9550  198800         house
# 1           1     20246399           2170  349000         house
# 2           2     20245215           4102  199900         house
# 3           3     20245396           9620  349000         house
# 4           4     20245133           1200  795000         house
# 5           5     20244275           8500  455000         house
# 6           6     20244687           9860  455000         house
# 7           7     20241273           6220  315000         house
# 8           8     20242318           1120  477000         house
# 9           9     20244297           4140  298000         house
#
#   Property subtype  Type of sale  Number of bedrooms  Living area m²  \
# 0            house           NaN                 3.0           125.0
# 1       town-house           NaN                 3.0           193.0
# 2            house           NaN                 3.0           131.0
# 3         bungalow           NaN                 4.0           237.0
# 4            house           NaN                 5.0           225.0
# 5            house           NaN                 4.0           187.0
# 6            house           NaN                 3.0           147.0
# 7            house           NaN                 2.0           100.0
# 8            house           NaN                 5.0           186.0
# 9            house           NaN                 4.0           242.0
#
#    Equipped kitchen  Furnished  Open fire  Terrace surface m²  Garden area m²  \
# 0                 0          0          1                45.0           106.0
# 1                 1          0          1                 NaN            53.0
# 2                 1          0          1                40.0            30.0
# 3                 0          0          1                16.0           390.0
# 4                 1          0          1                15.0           120.0
# 5                 1          0          1                 NaN           100.0
# 6                 0          0          1                16.0            77.0
# 7                 0          0          1                14.0          1030.0
# 8                 0          0          1                30.0           120.0
# 9                 1          0          1                80.0           147.0
#
#    Number of facades  Swimming pool Building condition
# 0                2.0              0        To renovate
# 1                2.0              0      To be done up
# 2                2.0              0             As new
# 3                4.0              0        To renovate
# 4                2.0              0        To renovate
# 5                NaN              0               Good
# 6                3.0              0     Just renovated
# 7                4.0              0      To be done up
# 8                2.0              0             As new
# 9                2.0              0               Good
# (10479, 17)

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Property ID',
#  'Locality data',
#  'Price',
#  'Property type',
#  'Property subtype',
#  'Type of sale',
#  'Number of bedrooms',
#  'Living area m²',
#  'Equipped kitchen',
#  'Furnished',
#  'Open fire',
#  'Terrace surface m²',
#  'Garden area m²',
#  'Number of facades',
#  'Swimming pool',
#  'Building condition']

# %% [markdown]
# ### Remove 'apartment-block' from Property subtype

# %%
df = df[df["Property subtype"].str.contains("apartment-block") == False]
display(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/immoeliza_scraping/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Property subtype'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df = df[df["Property subtype"].str.contains("apartment-block") == False]
#       2 display(df.head(10))
#
# File ~/immoeliza_scraping/venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/immoeliza_scraping/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Property subtype'

# %% [markdown]
# ### Remove unwanted columns

# %%
df.drop(labels=['Property subtype', 'Type of sale'], axis=1, inplace=True)

# %%
display(df.head(10))
df.shape
# Out:
#    Unnamed: 0  Property ID  Locality data   Price Property type  \
# 0           0     20245694           9550  198800         house
# 1           1     20246399           2170  349000         house
# 2           2     20245215           4102  199900         house
# 3           3     20245396           9620  349000         house
# 4           4     20245133           1200  795000         house
# 5           5     20244275           8500  455000         house
# 6           6     20244687           9860  455000         house
# 7           7     20241273           6220  315000         house
# 8           8     20242318           1120  477000         house
# 9           9     20244297           4140  298000         house
#
#    Number of bedrooms  Living area m²  Equipped kitchen  Furnished  Open fire  \
# 0                 3.0           125.0                 0          0          1
# 1                 3.0           193.0                 1          0          1
# 2                 3.0           131.0                 1          0          1
# 3                 4.0           237.0                 0          0          1
# 4                 5.0           225.0                 1          0          1
# 5                 4.0           187.0                 1          0          1
# 6                 3.0           147.0                 0          0          1
# 7                 2.0           100.0                 0          0          1
# 8                 5.0           186.0                 0          0          1
# 9                 4.0           242.0                 1          0          1
#
#    Terrace surface m²  Garden area m²  Number of facades  Swimming pool  \
# 0                45.0           106.0                2.0              0
# 1                 NaN            53.0                2.0              0
# 2                40.0            30.0                2.0              0
# 3                16.0           390.0                4.0              0
# 4                15.0           120.0                2.0              0
# 5                 NaN           100.0                NaN              0
# 6                16.0            77.0                3.0              0
# 7                14.0          1030.0                4.0              0
# 8                30.0           120.0                2.0              0
# 9                80.0           147.0                2.0              0
#
#   Building condition
# 0        To renovate
# 1      To be done up
# 2             As new
# 3        To renovate
# 4        To renovate
# 5               Good
# 6     Just renovated
# 7      To be done up
# 8             As new
# 9               Good
# (10114, 15)

# %% [markdown]
# ### Remove unwanted listings with 'Number of bedrooms' as 'Nan'

# %% [markdown]
# ### Count number of missing values per column

# %%
missing_values_column = df.isnull().sum()
print(missing_values_column)
# Out:
# Unnamed: 0               0
# Property ID              0
# Locality data            0
# Price                    0
# Property type            0
# Number of bedrooms       0
# Living area m²         133
# Equipped kitchen         0
# Furnished                0
# Open fire                0
# Terrace surface m²    5239
# Garden area m²        7342
# Number of facades     3084
# Swimming pool            0
# Building condition     957
# dtype: int64

# %%
nan_rows_livingarea = df[df['Living area m²'].isna()]
print(nan_rows_livingarea)
# Out:
#        Unnamed: 0  Property ID  Locality data   Price Property type  \
# 397           397     20235943           8540  219000         house
# 577           577     20246246           4460  179000         house
# 595           595     20228928           6224  149900         house
# 698           698     20244894           4420  249000         house
# 778           778     20246794           6970  300000         house
# ...           ...          ...            ...     ...           ...
# 10432       10432     11180221           8400  250000     apartment
# 10434       10434     11180222           8400  255000     apartment
# 10442       10442     11128760           1180  290000     apartment
# 10449       10449     20185488           8430  165000     apartment
# 10460       10460     20204017           8300  600000     apartment
#
#        Number of bedrooms  Living area m²  Equipped kitchen  Furnished  \
# 397                   3.0             NaN                 0          0
# 577                   3.0             NaN                 1          0
# 595                   3.0             NaN                 0          0
# 698                   3.0             NaN                 1          0
# 778                   4.0             NaN                 0          0
# ...                   ...             ...               ...        ...
# 10432                 2.0             NaN                 0          0
# 10434                 2.0             NaN                 0          0
# 10442                 2.0             NaN                 1          0
# 10449                 1.0             NaN                 0          0
# 10460                 2.0             NaN                 0          1
#
#        Open fire  Terrace surface m²  Garden area m²  Number of facades  \
# 397            1                 NaN             NaN                NaN
# 577            1                28.0            94.0                3.0
# 595            1                 NaN           139.0                3.0
# 698            1                25.0           257.0                2.0
# 778            1                 NaN             NaN                4.0
# ...          ...                 ...             ...                ...
# 10432          1                 7.0             NaN                NaN
# 10434          1                 7.0             NaN                NaN
# 10442          1                 3.0             NaN                2.0
# 10449          1                 NaN             NaN                NaN
# 10460          1                 NaN             NaN                NaN
#
#        Swimming pool Building condition
# 397                0               Good
# 577                0               Good
# 595                0        To renovate
# 698                0               Good
# 778                0               Good
# ...              ...                ...
# 10432              0     Just renovated
# 10434              0     Just renovated
# 10442              0               Good
# 10449              0        To renovate
# 10460              0               Good
#
# [133 rows x 15 columns]

# %%
# Filter to get only duplicate rows
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Property ID, Locality data, Price, Property type, Property subtype, Type of sale, Number of bedrooms, Living area m², Equipped kitchen, Furnished, Open fire, Terrace surface m², Garden area m², Number of facades, Swimming pool, Building condition]
# Index: []

# %% [markdown]
# ### Create new csv file

# %%
df.to_csv('Data/Raw/sanitized_property_listings_Kelli.csv', index=False)
