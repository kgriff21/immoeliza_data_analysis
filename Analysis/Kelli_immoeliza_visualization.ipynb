# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker

# Load your CSV file
df = pd.read_csv('../Archive/sanitized_property_listings_Kelli.csv')

# Check if df is None
if df is None:
    print("DataFrame not loaded correctly, df is None.")
else:
    print("DataFrame loaded successfully.")

# Display the first few rows in a more readable format
display(df.head(10))

# Check the shape of the DataFrame
print(df.shape)  # This will display the shape of the DataFrame
# Out:
# DataFrame loaded successfully.
#    Unnamed: 0  Property ID  Locality data   Price Property type  \
# 0           0     20245694           9550  198800         house
# 1           1     20246399           2170  349000         house
# 2           2     20245215           4102  199900         house
# 3           3     20245396           9620  349000         house
# 4           4     20245133           1200  795000         house
# 5           5     20244275           8500  455000         house
# 6           6     20244687           9860  455000         house
# 7           7     20241273           6220  315000         house
# 8           8     20242318           1120  477000         house
# 9           9     20244297           4140  298000         house
#
#    Number of bedrooms  Living area m²  Equipped kitchen  Furnished  Open fire  \
# 0                 3.0           125.0                 0          0          1
# 1                 3.0           193.0                 1          0          1
# 2                 3.0           131.0                 1          0          1
# 3                 4.0           237.0                 0          0          1
# 4                 5.0           225.0                 1          0          1
# 5                 4.0           187.0                 1          0          1
# 6                 3.0           147.0                 0          0          1
# 7                 2.0           100.0                 0          0          1
# 8                 5.0           186.0                 0          0          1
# 9                 4.0           242.0                 1          0          1
#
#    Terrace surface m²  Garden area m²  Number of facades  Swimming pool  \
# 0                45.0           106.0                2.0              0
# 1                 NaN            53.0                2.0              0
# 2                40.0            30.0                2.0              0
# 3                16.0           390.0                4.0              0
# 4                15.0           120.0                2.0              0
# 5                 NaN           100.0                NaN              0
# 6                16.0            77.0                3.0              0
# 7                14.0          1030.0                4.0              0
# 8                30.0           120.0                2.0              0
# 9                80.0           147.0                2.0              0
#
#   Building condition
# 0        To renovate
# 1      To be done up
# 2             As new
# 3        To renovate
# 4        To renovate
# 5               Good
# 6     Just renovated
# 7      To be done up
# 8             As new
# 9               Good
# (10114, 15)

# %% [markdown]
# ### Further data cleaning

# %%
df.drop(labels=['Number of facades'], axis=1, inplace=True)

# %%
# Drop rows with NaN in specific columns without assignment
df.dropna(subset=['Living area m²', 'Number of bedrooms', 'Building condition'], inplace=True)

# Check the new shape of df
print(df.shape)

df.to_csv("../Data/Cleaned/sanitized_property_listings_Kelli_final.csv", index=False)
# Out:
# (9033, 15)

# %% [markdown]
# ### Find outliers for different datasets with Seaborn

# %% [markdown]
# #### Property Prices boxplot listings below 1 million euros

# %%
# Sort the DataFrame by 'Price' in descending order and exclude the first 16 rows. These were checked as 'bad data' outliers.
df_sorted = df.sort_values(by='Price', ascending=False).iloc[16:]
df_sorted = df[df['Price'] < 1000000]

# Exclude properties about 1mil, and why. Collect list of assumptions. Together as a team say we do not work with houses over 1 mil and that's what the other should work with.

# %% [markdown]
# ### Comparing boxplots before and after manual outlier removal calculation
# Conclusion:
#     The first boxplot (before outlier removal) is useful to understand the full range and outlier impact on property prices.
#     The second boxplot (after outlier removal) gives a better representation of the central market trends and is less affected by extreme values.
#     By comparing the two boxplots, you can see how outliers impact the central tendency (median) and the spread of data. Removing them provides a cleaner and more focused view of the typical property prices.

# %%
# Plot before outlier removal
plt.figure(figsize=(4, 5))
sns.boxplot(y='Price', data=df_sorted, color="skyblue")
plt.title('Boxplot of Property Prices Before Outlier Removal', fontsize=16, fontweight='bold', pad=20)
plt.ylabel('Price')
plt.yticks(yticks, [f'€{y:,.0f}' for y in yticks])
plt.ylim(0, 1000000)
yticks = np.arange(0, 1000000 + 100000, 100000)  # Create y-ticks at intervals of 100,000 euros
plt.yticks(yticks, [f'€{y:,.0f}' for y in yticks])  # Format y-tick labels with euro symbol

median_price = df_sorted['Price'].median()
plt.text(0, median_price, f'€{median_price:,.0f}', ha='center', va='bottom', fontsize=12, color='black',
         fontweight='bold')
plt.show()

# %%
# IQR
# Calculate the upper and lower limits based on IQR
Q1 = df_sorted['Price'].quantile(0.25)
Q3 = df_sorted['Price'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Identify the indices of rows that are upper and lower outliers
outliers = df_sorted[(df_sorted['Price'] < lower) | (df_sorted['Price'] > upper)].index

# Remove all outliers from the DataFrame
df_cleaned = df_sorted.drop(index=outliers)

# Plot after outlier removal
plt.figure(figsize=(4, 5))
sns.boxplot(y='Price', data=df_cleaned, color="skyblue")
plt.title('Boxplot of Property Prices After Outlier Removal', fontsize=16, fontweight='bold', pad=20)
plt.ylabel('Price')

max_value = df_cleaned['Price'].max()

plt.ylim(0, 1000000)
yticks = np.arange(0, 1000000 + 100000, 100000)  # Create y-ticks at intervals of 100,000 euros
plt.yticks(yticks, [f'€{y:,.0f}' for y in yticks])  # Format y-tick labels with euro symbol

# Add an annotation for the median value inside the box
median_price = df_cleaned['Price'].median()
plt.text(0, median_price, f'€{median_price:,.0f}', ha='center', va='bottom', fontsize=12, 
         color='black', fontweight='bold')

plt.show()

# %% [markdown]
# ### Histogram to compare price distribution before and after outlier removal
# The bars in the histogram are grouped into bins based on the range of values they represent. They are essentially ranges of the price values. The width of each bin determines how many values will be grouped together within that bin. For instance, if you have prices ranging from €0 to €1,000,000, and you use 30 bins, each bin would represent a range of approximately €33,333.
#
# Calculate the upper and lower limits based on IQR (interquartile range).
#
# Frequency refers to the count of data points (or number of occurrences) that fall within each bin of the histogram.
#
# Impact of Outliers on Data:
#     In the before histogram, the long tail towards the higher end indicates that there were properties significantly more expensive than the rest, causing positive skew.
#     In the after histogram, removing these extreme values leads to a more balanced representation of the typical property prices, focusing on the core data.
#
# Central Tendency:
#     The peak of the histogram after outlier removal is more indicative of the true central tendency of property prices, as it is not pulled by extreme high values.
#     The mean and median values become more representative of the majority of the properties after outliers are removed.

# %%
def histogram_outlier_removal(dataset_clean, dataset_outliers):
    plt.figure(figsize=(10, 5))
    # Plot a histogram to compare price distribution before and after outlier removal
    sns.histplot(dataset_outliers['Price'], color='blue', label='Before Outlier Removal', kde=True, bins=30)
    sns.histplot(dataset_clean['Price'], color='orange', label='After Outlier Removal', kde=True, bins=30)
    
    plt.title('Price Distribution Before and After Outlier Removal', fontsize=16, fontweight='bold')
    plt.xlabel('Price (€)')
    plt.ylabel('Frequency (number of occurrences)')
    plt.legend()

    # Set x-axis tick labels to add more points, at intervals of 100,000 euros
    max_price = max(dataset_outliers['Price'].max(), dataset_clean['Price'].max())  # Get the maximum value from both datasets
    tick_interval = 100000  # Set tick interval at 100,000 euros
    ticks = np.arange(0, max_price + tick_interval, tick_interval)  # Create an array of tick positions at 100,000 intervals
    plt.xticks(ticks, [f'€{int(x):,}' for x in ticks])  # Set the x-axis tick labels with formatting
    plt.show()
    
histogram_outlier_removal(df_cleaned, df_sorted)

# %%
# Filter the DataFrame to find properties with Price > 1,000,000
properties_above_1M = df[df['Price'] > 1000000]
count_above_1M = properties_above_1M.shape[0]
print(f'There are {count_above_1M} properties with a price above 1,000,000.')
# Out:
# There are 677 properties with a price above 1,000,000.

# %% [markdown]
# ### Subset data into low, mid and high prices including listings over 1 million euros.

# %%
# 1. Define price groups
def assign_price_category(price):
    if price <= 300000:
        return 'Low'
    elif price >= 300000 and price <= 700000:
        return 'Mid'
    else:
        return 'High'

# Apply price group categorization to the original DataFrame
df['Price category'] = df['Price'].apply(assign_price_category)
# 2. Calculate Outliers Within Each Group
def identify_outliers(group):
    Q1 = df['Price'].quantile(0.25)
    Q3 = df['Price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return group[(group['Price'] >= lower_bound) & (group['Price'] <= upper_bound)]

# Split the data into groups and remove outliers within each group
low_group = df[df['Price category'] == 'Low']
mid_group = df[df['Price category'] == 'Mid']
high_group = df[df['Price category'] == 'High']

# Identify and retain non-outliers within each group
low_group_clean = identify_outliers(low_group)
mid_group_clean = identify_outliers(mid_group)
high_group_clean = identify_outliers(high_group)

print(low_group_clean.head)
# Step 3: Plot Stacked Histogram
plt.figure(figsize=(12, 8))
# Plot the original dataset as background
sns.histplot(df['Price'], color='blue', label='Before Outlier Removal', kde=True, bins=30, alpha=0.3)

# Plot the cleaned data for each price group
sns.histplot(low_group_clean['Price'], color='green', label='Low Price Group (Outliers Removed)', kde=True, bins=30, alpha=0.6)
sns.histplot(mid_group_clean['Price'], color='orange', label='Mid Price Group (Outliers Removed)', kde=True, bins=30, alpha=0.6)
sns.histplot(high_group_clean['Price'], color='red', label='High Price Group (Outliers Removed)', kde=True, bins=30, alpha=0.6)

plt.title('Price Distribution Before and After Outlier Removal by Price Category', fontsize=16, fontweight='bold')
plt.xlabel('Price (€)')
plt.ylabel('Frequency')
plt.legend()
# Set x-axis tick labels for better visualization
max_price = df['Price'].max()  # Get the maximum value from the dataset
tick_interval = 100000  # Set tick interval at 100,000 euros
ticks = np.arange(0, max_price + tick_interval, tick_interval)  # Create an array of tick positions at 100,000 intervals
plt.xticks(ticks, [f'€{int(x):,}' for x in ticks])  # Set the x-axis tick labels with formatting

plt.show()
# Out:
# <bound method NDFrame.head of        Unnamed: 0  Property ID  Locality data   Price Property type  \
# 0               0     20245694           9550  198800         house
# 2               2     20245215           4102  199900         house
# 9               9     20244297           4140  298000         house
# 11             11     20246094           4460  132000         house
# 14             14     20244012           9772  250000         house
# ...           ...          ...            ...     ...           ...
# 10100       10464     20214536           8434  239000     apartment
# 10105       10469     20234724           4100   95000     apartment
# 10106       10471     20233925           4000  164000     apartment
# 10107       10472     20233920           4130  299000     apartment
# 10112       10477     11381527           8800  299000     apartment
#
#        Number of bedrooms  Living area m²  Equipped kitchen  Furnished  \
# 0                     3.0           125.0                 0          0
# 2                     3.0           131.0                 1          0
# 9                     4.0           242.0                 1          0
# 11                    2.0            76.0                 0          0
# 14                    3.0           141.0                 0          0
# ...                   ...             ...               ...        ...
# 10100                 2.0            59.0                 0          0
# 10105                 1.0            60.0                 0          0
# 10106                 1.0            78.0                 0          0
# 10107                 3.0           147.0                 1          0
# 10112                 2.0           117.0                 1          0
#
#        Open fire  Terrace surface m²  Garden area m²  Number of facades  \
# 0              1                45.0           106.0                2.0
# 2              1                40.0            30.0                2.0
# 9              1                80.0           147.0                2.0
# 11             1                20.0           105.0                2.0
# 14             1                 NaN           300.0                4.0
# ...          ...                 ...             ...                ...
# 10100          1                 NaN             NaN                NaN
# 10105          1                 NaN             NaN                3.0
# 10106          1                 NaN             NaN                2.0
# 10107          1                20.0           371.0                2.0
# 10112          1                79.0             NaN                NaN
#
#        Swimming pool Building condition Price Category Price category
# 0                  0        To renovate            Low            Low
# 2                  0             As new            Low            Low
# 9                  0               Good            Low            Low
# 11                 0        To renovate            Low            Low
# 14                 0        To renovate            Low            Low
# ...              ...                ...            ...            ...
# 10100              0     Just renovated            Low            Low
# 10105              0        To renovate            Low            Low
# 10106              0               Good            Low            Low
# 10107              0     Just renovated            Low            Low
# 10112              0               Good            Low            Low
#
# [3642 rows x 17 columns]>

# %%
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 6))

# Create a bar plot that shows the average price per number of bedrooms
sns.barplot(x="Number of bedrooms", y="Price", data=df, estimator=np.mean, ax=ax)

# Set title and labels
ax.set_title('Average Property Price by Number of Bedrooms', fontsize=16, fontweight='bold')
ax.set_xlabel('Number of Bedrooms', fontsize=14)
ax.set_ylabel('Average Price (€)', fontsize=14)

# Format y-axis with commas for thousands separator
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# Show the plot
plt.show()

# %% [markdown]
# #### Number of Bedrooms excluding listings over 1 million euros
# Central Tendency:
#     The box of the boxplot represents the interquartile range (IQR), which covers the middle 50% of the data.
#     The median (middle line of the box) is at 2 bedrooms, indicating that half of the properties have 2 bedrooms or fewer, while the other half has more.
#
# The IQR stretches between 2 and 3 bedrooms, indicating that most properties fall within this range. Meaning, most properties have either 2 or 3 bedrooms which is standard for family homes or apartments.
#
# Outliers:
#     Several outliers above the whisker (4 bedrooms). Short whisker length means that most data is within the whiskers and there's a fairly consistent pattern for number of bedrooms except outliers.

# %%
def number_of_bedrooms(df, title):    
    plt.figure(figsize=(3, 5))
    sns.boxplot(y='Number of bedrooms', data=df, color="skyblue")
    plt.title(title, fontsize=16, fontweight='bold')
    plt.ylabel('Number of bedrooms')
    # Set y-axis tick labels to add more points (in this case, we use integers for the number of bedrooms)
    max_bedrooms = df['Number of bedrooms'].max()  # Get the maximum number of bedrooms
    yticks = np.arange(0, max_bedrooms + 1, 1)  # Create an array of tick positions with a step of 1 (integers only)
    plt.yticks(yticks)  # Set the y-axis tick labels to be the integer values of bedrooms
    
    plt.show()

number_of_bedrooms(df, "Number of Bedrooms Before Outlier Removal")
number_of_bedrooms(df_sorted, "Number of Bedrooms After Outlier Removal")

# %% [markdown]
# ### Barplot for Number of Bedrooms: Outliers calculated and removed

# %%
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(10, 6))

# Create a bar plot for the number of bedrooms (distribution of bedrooms)
sns.countplot(x="Number of bedrooms", data=df_sorted, ax=ax)

# Set title and labels
ax.set_title('Distribution of Number of Bedrooms', fontsize=16, fontweight='bold')
ax.set_xlabel('Number of Bedrooms', fontsize=14)
ax.set_ylabel('Count of Listings', fontsize=14)

# IQR
# Calculate the upper and lower limits based on IQR
Q1 = df_sorted['Price'].quantile(0.25)
Q3 = df_sorted['Price'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

# Identify the indices of rows that are upper and lower outliers
outliers = df_sorted[(df_sorted['Price'] < lower) | (df_sorted['Price'] > upper)].index

# Remove all outliers from the DataFrame
df_cleaned = df_sorted.drop(index=outliers)

plt.show()
