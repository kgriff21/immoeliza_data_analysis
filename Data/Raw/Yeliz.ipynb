# %%
import pandas as pd
import numpy as np

df=pd.read_csv('property_information(Kelly).csv')
df.head()
# Out:
#    Unnamed: 0  Property ID  Locality data   Price Property type  \
# 0           0     20241273           6220  315000         house
# 1           1     20240496           8790  299000         house
# 2           2     20239177           7890  349000         house
# 3           3     20238847           9600  349000         house
# 4           4     20236558           2018  389900         house
#
#   Property subtype  Type of sale  Number of bedrooms  Living area m²  \
# 0            house           NaN                 2.0           100.0
# 1            house           NaN                 4.0           354.0
# 2            house           NaN                 3.0           138.0
# 3            house           NaN                 3.0           138.0
# 4            house           NaN                 3.0           150.0
#
#    Equipped kitchen  Furnished  Open fire  Terrace surface m²  Garden area m²  \
# 0                 0          0          1                14.0          1030.0
# ...
